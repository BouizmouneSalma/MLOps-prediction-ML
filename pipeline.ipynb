# %% [markdown]
# ```
# Data → Training Pipeline → MLflow (Track + Register)
#
#                      ↓
#                 Best Model
#                      ↓
#               FastAPI Inference API
#                      ↓
#                 Docker Container
#                      ↓
#      GitHub Actions (CI/CD + CT)
#                      ↓
#         Deployed Service (VM / K8s / Cloud)
#                      ↓
#       Prometheus ← Metrics ← FastAPI
#                      ↓
#                  Grafana Dashboards
#
# ```
